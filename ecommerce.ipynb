# %% [markdown]
# E-commerce
#
# Customers
# Products
# Administartors
#
#
# pk -- primary key    fk -- foreign key
#
# Customers - pay money, signup ,addto cart, wallet
#
# email, varchar (250)
# phone,  int(10)
# customer_id  =Primary key uuid
# First_name  varchar(250)
# Last_name  varchar(250)
# Address varchar(250)
# Gender  varcahr(7)
# Date_of_birth Date
#
#
#
# Products -
#
# Product id  uuid  pk
# Product name varchar(250)
# Price  money
# Product details  varchar(250)
# varaint_id  fk
# category_id  fk
#
#
#
# Order-
#
# Order id uuid  pk
# product id  uuid fk
# customer id fk
# order status varchar
# payment status varchar
#
#
# Transaction-
#
# payment id  uuid pk
# payment status varchar
# order id uuid fk
#
#
# Cart details-
#
# product id --fk
# no of products
#
# shipments-
#
# shipment_id uuid pk
# shipmnet_date date
# shipment_status varchar
# order_id uuid fk
#
# Variants-
#
# variant_id uuid pk
# product_id uuid fk
# variant_details
#
#
# Category-
#
# Categoryid uuid pk
# category_type varchar
#
#
# Administarators-
#
# administaror name
# admin_id
# admin_level
